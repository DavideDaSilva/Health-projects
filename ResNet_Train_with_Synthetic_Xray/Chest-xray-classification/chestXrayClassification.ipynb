# %%
# Uncomment the lines below and run the installations
#!pip install torch
#!pip install torchvision
#!pip install gradio

# %%
# Import libraries
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
from PIL import Image
import gradio as gr
from sklearn.metrics import precision_score, recall_score, accuracy_score

# %%
# Calculating the mean and standard deviation of the data set
def load_images_from_folder(folder, target_size=(256, 256)):
    images = []
    for filename in os.listdir(folder):
        img = cv2.imread(os.path.join(folder, filename), cv2.IMREAD_GRAYSCALE)
        if img is not None:
            img = cv2.resize(img, target_size)
            images.append(img)
    return images

def compute_mean_std(images):
    stacked_images = np.stack(images, axis=0)
    mean = np.mean(stacked_images)
    std = np.std(stacked_images)
    return mean, std


folder_path = r'C:\Users\Khomp\Desktop\Projetos SBC 2025\Official\Health-projects\ResNet_Train_with_Synthetic_Xray\Chest-xray-classification\checandoMEDIAeSD'
images = load_images_from_folder(folder_path)
mean, std = compute_mean_std(images)
print(f'Mean: {mean}')
print(f'Standard Deviation: {std}')
# Out:
# Mean: 126.81388519622467
# Standard Deviation: 83.99047158786409

# %%
# Defining data transformations for grayscale images with the computed mean and std
data_transforms = {
    'train': transforms.Compose([
        transforms.Grayscale(num_output_channels=1),  # Converting to grayscale
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([mean / 255], [std / 255])  # Normalizing using the computed mean and std
    ]),
    'val': transforms.Compose([
        transforms.Grayscale(num_output_channels=1),  # Converting to grayscale
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([mean / 255], [std / 255])  # Normalizing using the computed mean and std
    ]),
}

# %%
# Defining the data directory
data_dir = r'C:\Users\Khomp\Desktop\Projetos SBC 2025\Official\Health-projects\ResNet_Train_with_Synthetic_Xray\Chest-xray-classification\dataset'

# %%
# Creating data loaders
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x), data_transforms[x]) for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=4, shuffle=True, num_workers=4) for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
print(dataset_sizes)
class_names = image_datasets['train'].classes
print('Classes: ', class_names)
# Out:
# {'train': 182, 'val': 25}
# Classes:  ['real chest x-ray', 'synthetic chest x-ray']

# %%
# Loading the pre-trained ResNet-50 model
model = models.resnet50(pretrained=True)

# Freezing all layers except the final classification layer
for name, param in model.named_parameters():
    if "fc" in name:  # Unfreezing the final classification layer
        param.requires_grad = True
    else:
        param.requires_grad = False

# (Linha adicionado devido ao problema de overfitting) Adding Dropout to the final classification layer
'''
model.fc = nn.Sequential(
    nn.Dropout(p=0.5),  # 50% dropout rate
    nn.Linear(model.fc.in_features, len(class_names))
)
'''
# Defining the loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
'''
# (Linha adicionado devido ao problema de overfitting) Defining the optimizer with L2 regularization
# optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9, weight_decay=0.0001)  # Adjusting weight_decay value
'''
# Moving the model to the GPU if available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = model.to(device)
# Out:
# C:\Users\Khomp\USPesalqMBA\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\Khomp\USPesalqMBA\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# Training loop
num_epochs = 100
for epoch in range(num_epochs):
    for phase in ['train', 'val']:
        if phase == 'train':
            model.train()
        else:
            model.eval()
        running_loss = 0.0
        running_corrects = 0
        for inputs, labels in dataloaders[phase]:
            inputs = inputs.to(device)
            labels = labels.to(device)
            # Converting grayscale images to RGB
            if inputs.shape[1] == 1:
                inputs = inputs.repeat(1, 3, 1, 1)
            optimizer.zero_grad()
            with torch.set_grad_enabled(phase == 'train'):
                outputs = model(inputs)
                _, preds = torch.max(outputs, 1)
                loss = criterion(outputs, labels)
                if phase == 'train':
                    loss.backward()
                    optimizer.step()
            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)
        epoch_loss = running_loss / dataset_sizes[phase]
        epoch_acc = running_corrects.double() / dataset_sizes[phase]
        print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')
print("Done!")
# Out:
# train Loss: 1.8937 Acc: 0.5055
# val Loss: 0.7084 Acc: 0.6000
# train Loss: 0.5326 Acc: 0.7363
# val Loss: 1.5841 Acc: 0.4000
# train Loss: 0.3635 Acc: 0.8242
# val Loss: 2.2297 Acc: 0.2000
# train Loss: 0.4088 Acc: 0.7637
# val Loss: 0.5196 Acc: 0.8000
# train Loss: 0.4550 Acc: 0.8022
# val Loss: 1.1957 Acc: 0.7600
# train Loss: 0.5201 Acc: 0.7802
# val Loss: 2.6017 Acc: 0.1600
# train Loss: 0.5146 Acc: 0.7967
# val Loss: 1.1919 Acc: 0.7600
# train Loss: 0.3308 Acc: 0.8516
# val Loss: 0.6133 Acc: 0.8000
# train Loss: 0.2386 Acc: 0.9066
# val Loss: 1.5257 Acc: 0.5600
# train Loss: 0.2676 Acc: 0.8681
# val Loss: 2.6430 Acc: 0.1600
# train Loss: 0.8852 Acc: 0.7033
# val Loss: 4.4295 Acc: 0.0000
# train Loss: 0.6275 Acc: 0.7967
# val Loss: 4.8566 Acc: 0.0000
# train Loss: 0.2702 Acc: 0.8956
# val Loss: 2.0047 Acc: 0.4000
# train Loss: 0.3134 Acc: 0.8516
# val Loss: 1.3997 Acc: 0.7600
# train Loss: 0.2277 Acc: 0.9121
# val Loss: 2.5245 Acc: 0.2000
# train Loss: 0.2936 Acc: 0.8681
# val Loss: 2.4737 Acc: 0.1600
# train Loss: 0.4003 Acc: 0.8407
# val Loss: 3.3921 Acc: 0.1200
# train Loss: 0.3571 Acc: 0.8681
# val Loss: 0.9208 Acc: 0.8000
# train Loss: 0.4526 Acc: 0.8077
# val Loss: 2.7321 Acc: 0.2800
# train Loss: 0.3628 Acc: 0.8736
# val Loss: 1.4837 Acc: 0.6800
# train Loss: 0.1909 Acc: 0.9121
# val Loss: 0.7154 Acc: 0.8000
# train Loss: 0.3464 Acc: 0.8736
# val Loss: 2.3746 Acc: 0.3200
# train Loss: 0.2384 Acc: 0.8956
# val Loss: 2.2782 Acc: 0.3600
# train Loss: 0.4541 Acc: 0.8407
# val Loss: 2.2237 Acc: 0.3200
# train Loss: 0.2606 Acc: 0.8846
# val Loss: 1.9953 Acc: 0.4800
# train Loss: 0.2728 Acc: 0.8791
# val Loss: 3.3865 Acc: 0.2000
# train Loss: 0.2558 Acc: 0.9231
# val Loss: 1.6756 Acc: 0.4800
# train Loss: 0.2656 Acc: 0.9066
# val Loss: 0.6539 Acc: 0.8000
# train Loss: 0.4249 Acc: 0.8352
# val Loss: 5.6193 Acc: 0.0000
# train Loss: 0.5231 Acc: 0.8187
# val Loss: 1.7071 Acc: 0.6000
# train Loss: 0.4344 Acc: 0.8516
# val Loss: 1.1098 Acc: 0.7600
# train Loss: 0.2892 Acc: 0.8681
# val Loss: 1.0832 Acc: 0.7600
# train Loss: 0.3852 Acc: 0.8681
# val Loss: 1.5218 Acc: 0.6400
# train Loss: 0.3396 Acc: 0.8626
# val Loss: 2.2727 Acc: 0.5200
# train Loss: 0.3547 Acc: 0.8736
# val Loss: 1.4938 Acc: 0.6800
# train Loss: 0.3161 Acc: 0.8901
# val Loss: 2.3307 Acc: 0.4000
# train Loss: 0.2759 Acc: 0.8791
# val Loss: 3.4226 Acc: 0.1200
# train Loss: 0.2768 Acc: 0.8901
# val Loss: 1.1418 Acc: 0.7600
# train Loss: 0.2812 Acc: 0.8681
# val Loss: 2.7428 Acc: 0.3600
# train Loss: 0.3472 Acc: 0.8736
# val Loss: 2.2749 Acc: 0.5200
# train Loss: 0.3765 Acc: 0.8516
# val Loss: 1.1731 Acc: 0.7200
# train Loss: 0.3190 Acc: 0.8736
# val Loss: 1.5883 Acc: 0.6400
# train Loss: 0.3373 Acc: 0.8791
# val Loss: 6.3312 Acc: 0.0000
# train Loss: 0.2507 Acc: 0.9066
# val Loss: 2.0697 Acc: 0.6000
# train Loss: 0.4002 Acc: 0.8626
# val Loss: 4.1951 Acc: 0.1600
# train Loss: 0.4131 Acc: 0.8462
# val Loss: 3.3617 Acc: 0.1600
# train Loss: 0.4096 Acc: 0.8242
# val Loss: 1.9242 Acc: 0.5600
# train Loss: 0.3894 Acc: 0.8571
# val Loss: 9.0549 Acc: 0.0000
# train Loss: 0.4649 Acc: 0.8352
# val Loss: 2.9475 Acc: 0.3200
# train Loss: 0.1052 Acc: 0.9560
# val Loss: 2.8700 Acc: 0.3200
# train Loss: 0.3515 Acc: 0.8571
# val Loss: 3.2576 Acc: 0.2000
# train Loss: 0.3980 Acc: 0.8571
# val Loss: 1.6700 Acc: 0.6400
# train Loss: 0.3919 Acc: 0.8571
# val Loss: 2.8324 Acc: 0.2400
# train Loss: 0.3459 Acc: 0.8956
# val Loss: 6.1350 Acc: 0.0000
# train Loss: 0.2901 Acc: 0.8901
# val Loss: 2.4059 Acc: 0.2800
# train Loss: 0.2572 Acc: 0.9011
# val Loss: 0.9498 Acc: 0.7600
# train Loss: 0.3440 Acc: 0.8626
# val Loss: 1.7497 Acc: 0.5600
# train Loss: 0.3889 Acc: 0.8352
# val Loss: 1.4443 Acc: 0.6000
# train Loss: 0.4493 Acc: 0.8681
# val Loss: 0.2641 Acc: 0.9200
# train Loss: 0.4212 Acc: 0.8516
# val Loss: 3.1163 Acc: 0.2800
# train Loss: 0.4164 Acc: 0.8407
# val Loss: 1.0297 Acc: 0.7600
# train Loss: 0.8040 Acc: 0.7527
# val Loss: 5.3836 Acc: 0.0400
# train Loss: 0.3753 Acc: 0.8626
# val Loss: 1.8906 Acc: 0.6400
# train Loss: 0.2306 Acc: 0.9066
# val Loss: 2.5822 Acc: 0.3600
# train Loss: 0.2175 Acc: 0.9121
# val Loss: 2.2267 Acc: 0.5200
# train Loss: 0.1744 Acc: 0.9286
# val Loss: 1.8475 Acc: 0.6800
# train Loss: 0.3600 Acc: 0.8901
# val Loss: 3.9557 Acc: 0.2000
# train Loss: 0.2138 Acc: 0.9176
# val Loss: 5.5568 Acc: 0.0400
# train Loss: 0.1562 Acc: 0.9451
# val Loss: 3.2128 Acc: 0.2800
# train Loss: 0.2750 Acc: 0.9066
# val Loss: 5.1273 Acc: 0.0400
# train Loss: 0.1983 Acc: 0.9396
# val Loss: 3.3361 Acc: 0.2400
# train Loss: 0.2524 Acc: 0.8791
# val Loss: 3.3989 Acc: 0.2400
# train Loss: 0.1878 Acc: 0.9121
# val Loss: 5.0358 Acc: 0.0800
# train Loss: 0.2850 Acc: 0.9011
# val Loss: 2.2717 Acc: 0.4400
# train Loss: 0.1868 Acc: 0.9121
# val Loss: 3.6331 Acc: 0.2000
# train Loss: 0.2518 Acc: 0.9121
# val Loss: 7.5769 Acc: 0.0000
# train Loss: 0.1709 Acc: 0.9341
# val Loss: 4.7291 Acc: 0.0400
# train Loss: 0.3152 Acc: 0.8626
# val Loss: 4.1110 Acc: 0.1600
# train Loss: 0.3304 Acc: 0.8901
# val Loss: 1.7563 Acc: 0.6400
# train Loss: 0.2369 Acc: 0.9176
# val Loss: 2.2607 Acc: 0.5200
# train Loss: 0.3387 Acc: 0.8901
# val Loss: 2.5811 Acc: 0.3600
# train Loss: 0.3207 Acc: 0.8956
# val Loss: 2.7648 Acc: 0.3200
# train Loss: 0.3683 Acc: 0.8791
# val Loss: 2.5743 Acc: 0.4400
# train Loss: 0.2852 Acc: 0.9121
# val Loss: 4.8293 Acc: 0.0400
# train Loss: 0.5074 Acc: 0.8297
# val Loss: 2.4186 Acc: 0.5600
# train Loss: 0.2758 Acc: 0.8846
# val Loss: 5.3423 Acc: 0.0400
# train Loss: 0.3932 Acc: 0.8681
# val Loss: 2.3667 Acc: 0.5200
# train Loss: 0.3653 Acc: 0.8626
# val Loss: 4.7382 Acc: 0.0400
# train Loss: 0.4661 Acc: 0.8462
# val Loss: 3.6755 Acc: 0.2000
# train Loss: 0.4167 Acc: 0.8791
# val Loss: 5.6057 Acc: 0.0400
# train Loss: 0.4149 Acc: 0.8736
# val Loss: 3.4155 Acc: 0.2000
# train Loss: 0.3427 Acc: 0.8846
# val Loss: 3.4082 Acc: 0.1600
# train Loss: 0.2111 Acc: 0.9121
# val Loss: 3.7310 Acc: 0.1600
# train Loss: 0.4051 Acc: 0.8407
# val Loss: 3.2164 Acc: 0.2400
# train Loss: 0.1778 Acc: 0.9341
# val Loss: 3.5144 Acc: 0.1600
# train Loss: 0.1628 Acc: 0.9451
# val Loss: 4.7186 Acc: 0.0000
# train Loss: 0.3979 Acc: 0.8462
# val Loss: 2.9226 Acc: 0.3200
# train Loss: 0.5520 Acc: 0.8132
# val Loss: 1.2832 Acc: 0.6800
# train Loss: 0.3035 Acc: 0.8846
# val Loss: 1.2289 Acc: 0.6800
# train Loss: 0.1153 Acc: 0.9560
# val Loss: 1.4427 Acc: 0.6400
# Done!

# %%
# Evaluation
def evaluate_model(model, dataloaders, dataset_sizes, device):
    model.eval()
    for phase in ['train', 'val']:
        all_preds = []
        all_labels = []
        for inputs, labels in dataloaders[phase]:
            inputs = inputs.to(device)
            labels = labels.to(device)
            # Converting grayscale images to RGB
            if inputs.shape[1] == 1:
                inputs = inputs.repeat(1, 3, 1, 1)
            with torch.set_grad_enabled(False):
                outputs = model(inputs)
                _, preds = torch.max(outputs, 1)
                all_preds.extend(preds.cpu().numpy())
                all_labels.extend(labels.cpu().numpy())
        # Converting lists to NumPy arrays
        all_preds = np.array(all_preds)
        all_labels = np.array(all_labels)
        accuracy = accuracy_score(all_labels, all_preds)
        precision = precision_score(all_labels, all_preds, average='weighted')
        recall = recall_score(all_labels, all_preds, average='weighted')
        print(f'{phase} Accuracy: {accuracy:.4f}')
        print(f'{phase} Precision: {precision:.4f}')
        print(f'{phase} Recall: {recall:.4f} \n')

# Calling the function after training the model
evaluate_model(model, dataloaders, dataset_sizes, device)
# Out:
# train Accuracy: 0.9231
# train Precision: 0.9333
# train Recall: 0.9231
#
# val Accuracy: 0.6400
# val Precision: 1.0000
# val Recall: 0.6400
# C:\Users\Khomp\USPesalqMBA\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Saving the model
torch.save(model.state_dict(), 'chest_xray_classification_model.pth')

# %%
# Loading the saved model
model = models.resnet50(pretrained=True)
model.fc = nn.Linear(model.fc.in_features, 1000)  # Adjusting to match the original model's output units
model.load_state_dict(torch.load('chest_xray_classification_model.pth'))
model.eval()

# Creating a new model with the correct final layer
new_model = models.resnet50(pretrained=True)
new_model.fc = nn.Linear(new_model.fc.in_features, 2)  # Adjusting to match the desired output units
# Copying the weights and biases from the loaded model to the new model
new_model.fc.weight.data = model.fc.weight.data[0:2]  # Copying only the first 2 output units
new_model.fc.bias.data = model.fc.bias.data[0:2]
# Out:
# C:\Users\Khomp\USPesalqMBA\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\Khomp\USPesalqMBA\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# Defining the preprocessing function
def preprocess_image(image):
    preprocess = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
    input_tensor = preprocess(image)
    input_batch = input_tensor.unsqueeze(0)  # Add a batch dimension
    return input_batch

# Defining the prediction function
def predict(image):
    input_batch = preprocess_image(image)
    # Check if CUDA is available and use it if possible
    if torch.cuda.is_available():
        input_batch = input_batch.to('cuda')
        new_model.to('cuda')
    # Performing inference
    with torch.no_grad():
        output = new_model(input_batch)
        # Getting the predicted class
        _, predicted_class = output.max(1)
    class_names = ['real chest x-ray', 'synthetic chest x-ray']  # Updated class names
    predicted_class_name = class_names[predicted_class.item()]
    return predicted_class_name, image

# Creating the Gradio interface
def gradio_predict(image):
    predicted_class_name, image = predict(image)
    displayed_image = display_image_with_prediction(predicted_class_name, image)
    return predicted_class_name, displayed_image

iface = gr.Interface(
    fn=gradio_predict,
    inputs=gr.Image(type="pil"),
    outputs=["text", "image"],
    title="Chest X-ray Classification",
    description="Upload a chest x-ray image to classify it as real or synthetic."
)

# Launching the interface
iface.launch()

# Defining a function to display the image with the predicted class name
def display_image_with_prediction(predicted_class_name, image):
    image_np = np.array(image)
    plt.imshow(image_np, cmap='gray')
    plt.axis('off')
    plt.text(10, 10, f'Predicted: {predicted_class_name}', fontsize=12, color='white', backgroundcolor='red', weight='bold')
    plt.savefig("predicted_image.png")  # Save the plot as an image file
    return Image.open("predicted_image.png")
# Out:
# * Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
