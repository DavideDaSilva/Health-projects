# %%
# Uncomment the lines below and run the installations
#!pip install torch
#!pip install torchvision
#!pip install opencv-python
#!pip install gradio

# %%
# Importing libs
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
import gradio as gr
import os

# %%
# Calculating the mean and standard deviation of the data set
import os
import numpy as np
import cv2

def load_images_from_folder(folder, target_size=(256, 256)):
    images = []
    for filename in os.listdir(folder):
        img = cv2.imread(os.path.join(folder, filename), cv2.IMREAD_GRAYSCALE)
        if img is not None:
            img = cv2.resize(img, target_size)
            images.append(img)
    return images

def compute_mean_std(images):
    stacked_images = np.stack(images, axis=0)
    mean = np.mean(stacked_images)
    std = np.std(stacked_images)
    return mean, std

folder_path = r'C:\Users\Khomp\Desktop\Projetos SBC 2025\Official\Health-projects\Chest_Xray-classification - model_trained_with_synthetic_dada\checandoMEDIAeSD'

images = load_images_from_folder(folder_path)
mean, std = compute_mean_std(images)

print(f'Mean: {mean}')
print(f'Standard Deviation: {std}')
# Out:
# Mean: 141.33299049377442
# Standard Deviation: 79.09944681183063

# %%
# Defining data transformations for grayscale images with the computed mean and std
data_transforms = {
    'train': transforms.Compose([
        transforms.Grayscale(num_output_channels=1),  # Converting to grayscale
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([mean / 255], [std / 255])  # Normalizing using the computed mean and std
    ]),
    'val': transforms.Compose([
        transforms.Grayscale(num_output_channels=1),  # Converting to grayscale
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([mean / 255], [std / 255])  # Normalizing using the computed mean and std
    ]),
}

# %%
# Defining the data directory
data_dir = r'C:\Users\Khomp\Desktop\Projetos SBC 2025\Official\Health-projects\Chest_Xray-classification - model_trained_with_synthetic_dada\dataset'

# %%
# Creating data loaders
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x), data_transforms[x]) for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=4, shuffle=True, num_workers=4) for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
print(dataset_sizes)

class_names = image_datasets['train'].classes
class_names
# Out:
# {'train': 160, 'val': 40}
# ['healthy', 'tuberculosis']

# %%
# Loading the pre-trained ResNet-50 model
model = models.resnet50(pretrained=True)
# Out:
# C:\Users\Khomp\USPesalqMBA\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\Khomp\USPesalqMBA\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# Freezing all layers except the final classification layer
for name, param in model.named_parameters():
    if "fc" in name:  # Unfreezing the final classification layer
        param.requires_grad = True
    else:
        param.requires_grad = False

# %%
# Defining the loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)  # Using all parameters

# %%
# Moving the model to the GPU if available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# %%
# Training loop
num_epochs = 100
for epoch in range(num_epochs):
    for phase in ['train', 'val']:
        if phase == 'train':
            model.train()
        else:
            model.eval()

        running_loss = 0.0
        running_corrects = 0

        for inputs, labels in dataloaders[phase]:
            inputs = inputs.to(device)
            labels = labels.to(device)

            # Converting grayscale images to RGB
            if inputs.shape[1] == 1:
                inputs = inputs.repeat(1, 3, 1, 1)

            optimizer.zero_grad()

            with torch.set_grad_enabled(phase == 'train'):
                outputs = model(inputs)
                _, preds = torch.max(outputs, 1)
                loss = criterion(outputs, labels)

                if phase == 'train':
                    loss.backward()
                    optimizer.step()

            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)

        epoch_loss = running_loss / dataset_sizes[phase]
        epoch_acc = running_corrects.double() / dataset_sizes[phase]

        print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

print("Training complete!")
# Out:
# train Loss: 1.9916 Acc: 0.5188
# val Loss: 1.0677 Acc: 0.4750
# train Loss: 0.8244 Acc: 0.5687
# val Loss: 0.9810 Acc: 0.4750
# train Loss: 0.7572 Acc: 0.6188
# val Loss: 0.9702 Acc: 0.5250
# train Loss: 0.7842 Acc: 0.6375
# val Loss: 1.6076 Acc: 0.5000
# train Loss: 0.7200 Acc: 0.6562
# val Loss: 0.5586 Acc: 0.6750
# train Loss: 0.8602 Acc: 0.6125
# val Loss: 0.3765 Acc: 0.8250
# train Loss: 0.6420 Acc: 0.7188
# val Loss: 0.3990 Acc: 0.8500
# train Loss: 0.5277 Acc: 0.7562
# val Loss: 0.3148 Acc: 0.8750
# train Loss: 0.7079 Acc: 0.7188
# val Loss: 0.8939 Acc: 0.6000
# train Loss: 1.3548 Acc: 0.5563
# val Loss: 1.5987 Acc: 0.5250
# train Loss: 0.6641 Acc: 0.7438
# val Loss: 0.4046 Acc: 0.8500
# train Loss: 0.4920 Acc: 0.7750
# val Loss: 0.5364 Acc: 0.7750
# train Loss: 0.7836 Acc: 0.6375
# val Loss: 0.8806 Acc: 0.6250
# train Loss: 0.9269 Acc: 0.6188
# val Loss: 1.2200 Acc: 0.5500
# train Loss: 0.6715 Acc: 0.7063
# val Loss: 0.6301 Acc: 0.7000
# train Loss: 0.6584 Acc: 0.7375
# val Loss: 0.3413 Acc: 0.8000
# train Loss: 0.4000 Acc: 0.8125
# val Loss: 0.7595 Acc: 0.6250
# train Loss: 0.6300 Acc: 0.7375
# val Loss: 0.4949 Acc: 0.7750
# train Loss: 0.5842 Acc: 0.7250
# val Loss: 0.4989 Acc: 0.7750
# train Loss: 0.6858 Acc: 0.7063
# val Loss: 0.5446 Acc: 0.7750
# train Loss: 0.7173 Acc: 0.7063
# val Loss: 0.3383 Acc: 0.8500
# train Loss: 0.3957 Acc: 0.7937
# val Loss: 0.5549 Acc: 0.7250
# train Loss: 0.6921 Acc: 0.6875
# val Loss: 0.5631 Acc: 0.7250
# train Loss: 0.6499 Acc: 0.7312
# val Loss: 0.7989 Acc: 0.6750
# train Loss: 0.6382 Acc: 0.7562
# val Loss: 0.4131 Acc: 0.8000
# train Loss: 0.5316 Acc: 0.7375
# val Loss: 0.3182 Acc: 0.8250
# train Loss: 0.6497 Acc: 0.7000
# val Loss: 0.5311 Acc: 0.7500
# train Loss: 0.5649 Acc: 0.7375
# val Loss: 0.2972 Acc: 0.8500
# train Loss: 0.7951 Acc: 0.6937
# val Loss: 0.7573 Acc: 0.7250
# train Loss: 0.5721 Acc: 0.7312
# val Loss: 0.3779 Acc: 0.8000
# train Loss: 0.4275 Acc: 0.7812
# val Loss: 0.3687 Acc: 0.8500
# train Loss: 0.6608 Acc: 0.7125
# val Loss: 0.7800 Acc: 0.7250
# train Loss: 0.8109 Acc: 0.6875
# val Loss: 0.4792 Acc: 0.7250
# train Loss: 0.6031 Acc: 0.7000
# val Loss: 0.3063 Acc: 0.8750
# train Loss: 0.4995 Acc: 0.8000
# val Loss: 0.3038 Acc: 0.8750
# train Loss: 0.5601 Acc: 0.7375
# val Loss: 0.3462 Acc: 0.8500
# train Loss: 0.5460 Acc: 0.7438
# val Loss: 0.3199 Acc: 0.8000
# train Loss: 0.5041 Acc: 0.8187
# val Loss: 0.3928 Acc: 0.8250
# train Loss: 0.4017 Acc: 0.8063
# val Loss: 0.3823 Acc: 0.7750
# train Loss: 0.5428 Acc: 0.7750
# val Loss: 0.7974 Acc: 0.7500
# train Loss: 0.5437 Acc: 0.7250
# val Loss: 0.2608 Acc: 0.8750
# train Loss: 0.5529 Acc: 0.7500
# val Loss: 0.6581 Acc: 0.6750
# train Loss: 0.4903 Acc: 0.8063
# val Loss: 0.3910 Acc: 0.7750
# train Loss: 0.4025 Acc: 0.8125
# val Loss: 0.5090 Acc: 0.7500
# train Loss: 0.6106 Acc: 0.7188
# val Loss: 0.4655 Acc: 0.7500
# train Loss: 0.6572 Acc: 0.7312
# val Loss: 0.3878 Acc: 0.7500
# train Loss: 0.5077 Acc: 0.7750
# val Loss: 0.2969 Acc: 0.8500
# train Loss: 0.3658 Acc: 0.8250
# val Loss: 0.6568 Acc: 0.7000
# train Loss: 0.6006 Acc: 0.7312
# val Loss: 0.4757 Acc: 0.8000
# train Loss: 0.4675 Acc: 0.7812
# val Loss: 0.3168 Acc: 0.8750
# train Loss: 0.5925 Acc: 0.7312
# val Loss: 0.3262 Acc: 0.8500
# train Loss: 0.5941 Acc: 0.7250
# val Loss: 0.4029 Acc: 0.8250
# train Loss: 0.3944 Acc: 0.8438
# val Loss: 0.4248 Acc: 0.7750
# train Loss: 0.4314 Acc: 0.8125
# val Loss: 0.3518 Acc: 0.8250
# train Loss: 0.5164 Acc: 0.7688
# val Loss: 0.5049 Acc: 0.8250
# train Loss: 0.7023 Acc: 0.7312
# val Loss: 0.3827 Acc: 0.8000
# train Loss: 0.5115 Acc: 0.7688
# val Loss: 0.4920 Acc: 0.7750
# train Loss: 0.4055 Acc: 0.8063
# val Loss: 0.3627 Acc: 0.8250
# train Loss: 0.5203 Acc: 0.7438
# val Loss: 0.4679 Acc: 0.8000
# train Loss: 0.3945 Acc: 0.8125
# val Loss: 0.4056 Acc: 0.8250
# train Loss: 0.4608 Acc: 0.7625
# val Loss: 0.7623 Acc: 0.6500
# train Loss: 0.4646 Acc: 0.7875
# val Loss: 0.3985 Acc: 0.8000
# train Loss: 0.5433 Acc: 0.7750
# val Loss: 0.3390 Acc: 0.8500
# train Loss: 0.7588 Acc: 0.7125
# val Loss: 0.6345 Acc: 0.7500
# train Loss: 0.9765 Acc: 0.6562
# val Loss: 0.3161 Acc: 0.8250
# train Loss: 0.5288 Acc: 0.7562
# val Loss: 0.3312 Acc: 0.8750
# train Loss: 0.6051 Acc: 0.7438
# val Loss: 0.3703 Acc: 0.8000
# train Loss: 0.5378 Acc: 0.7750
# val Loss: 0.3918 Acc: 0.8000
# train Loss: 0.4037 Acc: 0.7812
# val Loss: 0.3339 Acc: 0.8000
# train Loss: 0.4631 Acc: 0.7688
# val Loss: 0.8858 Acc: 0.7250
# train Loss: 0.7723 Acc: 0.6750
# val Loss: 0.4069 Acc: 0.8250
# train Loss: 0.6967 Acc: 0.7562
# val Loss: 0.9578 Acc: 0.6250
# train Loss: 0.9531 Acc: 0.6250
# val Loss: 0.2810 Acc: 0.8750
# train Loss: 0.4541 Acc: 0.7812
# val Loss: 0.3105 Acc: 0.8000
# train Loss: 0.5694 Acc: 0.7500
# val Loss: 0.3568 Acc: 0.8250
# train Loss: 0.5155 Acc: 0.7750
# val Loss: 0.3037 Acc: 0.8750
# train Loss: 0.6484 Acc: 0.7375
# val Loss: 1.5128 Acc: 0.5250
# train Loss: 0.7995 Acc: 0.6937
# val Loss: 0.6210 Acc: 0.7250
# train Loss: 0.5415 Acc: 0.8000
# val Loss: 0.4171 Acc: 0.8000
# train Loss: 0.5248 Acc: 0.7812
# val Loss: 0.7210 Acc: 0.7750
# train Loss: 0.5936 Acc: 0.7625
# val Loss: 0.4013 Acc: 0.8500
# train Loss: 0.6438 Acc: 0.7812
# val Loss: 0.3032 Acc: 0.8500
# train Loss: 0.5768 Acc: 0.7812
# val Loss: 0.2973 Acc: 0.8500
# train Loss: 0.4445 Acc: 0.8250
# val Loss: 0.3254 Acc: 0.8000
# train Loss: 0.5267 Acc: 0.7562
# val Loss: 0.3926 Acc: 0.8250
# train Loss: 0.3508 Acc: 0.8875
# val Loss: 0.4681 Acc: 0.8000
# train Loss: 0.6160 Acc: 0.7750
# val Loss: 0.4942 Acc: 0.8000
# train Loss: 0.5649 Acc: 0.7625
# val Loss: 0.2951 Acc: 0.8750
# train Loss: 0.4400 Acc: 0.8250
# val Loss: 0.5502 Acc: 0.7750
# train Loss: 0.6281 Acc: 0.7438
# val Loss: 0.4662 Acc: 0.7500
# train Loss: 0.5151 Acc: 0.7500
# val Loss: 0.3602 Acc: 0.8500
# train Loss: 0.4759 Acc: 0.8187
# val Loss: 0.3560 Acc: 0.8750
# train Loss: 0.4920 Acc: 0.8125
# val Loss: 0.5747 Acc: 0.7500
# train Loss: 0.4728 Acc: 0.8000
# val Loss: 0.3467 Acc: 0.8750
# train Loss: 0.4283 Acc: 0.8000
# val Loss: 0.5512 Acc: 0.7500
# train Loss: 0.5151 Acc: 0.7812
# val Loss: 0.6298 Acc: 0.7250
# train Loss: 0.6653 Acc: 0.6937
# val Loss: 0.4265 Acc: 0.7500
# train Loss: 0.5040 Acc: 0.7688
# val Loss: 0.6080 Acc: 0.7000
# train Loss: 0.6202 Acc: 0.7500
# val Loss: 0.7681 Acc: 0.7000
# train Loss: 0.5826 Acc: 0.7750
# val Loss: 0.8115 Acc: 0.6750
# Training complete!

# %%
# =========================== Evaluation =========================

from sklearn.metrics import precision_score, recall_score, accuracy_score
import numpy as np

def evaluate_model(model, dataloaders, dataset_sizes, device):
    model.eval()

    for phase in ['train', 'val']:
        all_preds = []
        all_labels = []

        for inputs, labels in dataloaders[phase]:
            inputs = inputs.to(device)
            labels = labels.to(device)

            # Converting grayscale images to RGB
            if inputs.shape[1] == 1:
                inputs = inputs.repeat(1, 3, 1, 1)

            with torch.set_grad_enabled(False):
                outputs = model(inputs)
                _, preds = torch.max(outputs, 1)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

        # Converting lists to NumPy arrays
        all_preds = np.array(all_preds)
        all_labels = np.array(all_labels)

        accuracy = accuracy_score(all_labels, all_preds)
        precision = precision_score(all_labels, all_preds, average='weighted')
        recall = recall_score(all_labels, all_preds, average='weighted')

        print(f'{phase} Accuracy: {accuracy:.4f}')
        print(f'{phase} Precision: {precision:.4f}')
        print(f'{phase} Recall: {recall:.4f} \n')

# Calling the function after training the model
evaluate_model(model, dataloaders, dataset_sizes, device)
# Out:
# train Accuracy: 0.7875
# train Precision: 0.8215
# train Recall: 0.7875
#
# val Accuracy: 0.6750
# val Precision: 0.8030
# val Recall: 0.6750

# %%
# Saving the model
torch.save(model.state_dict(), 'chest_xray_classification_model_trained_with_synthetic_data.pth')

# %%
# Loading the saved model
model = models.resnet50(pretrained=True)
model.fc = nn.Linear(model.fc.in_features, 1000)  # Adjusting to match the original model's output units
model.load_state_dict(torch.load('chest_xray_classification_model_trained_with_synthetic_data.pth'))
model.eval()

# Creating a new model with the correct final layer
new_model = models.resnet50(pretrained=True)
new_model.fc = nn.Linear(new_model.fc.in_features, 2)  # Adjusting to match the desired output units
# Copying the weights and biases from the loaded model to the new model
new_model.fc.weight.data = model.fc.weight.data[0:2]  # Copying only the first 2 output units
new_model.fc.bias.data = model.fc.bias.data[0:2]
# Out:
# C:\Users\Khomp\USPesalqMBA\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\Khomp\USPesalqMBA\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# Defining the preprocessing function
import matplotlib.pyplot as plt
from PIL import Image

def preprocess_image(image):
    preprocess = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
    input_tensor = preprocess(image)
    input_batch = input_tensor.unsqueeze(0)  # Adding a batch dimension
    return input_batch

# Defining the prediction function
def predict(image):
    input_batch = preprocess_image(image)
    # Checking if CUDA is available and use it if possible
    if torch.cuda.is_available():
        input_batch = input_batch.to('cuda')
        new_model.to('cuda')
    # Performing inference
    with torch.no_grad():
        output = new_model(input_batch)
        # Getting the predicted class
        _, predicted_class = output.max(1)
    class_names = ['healthy', 'tuberculosis']  # Updated class names
    predicted_class_name = class_names[predicted_class.item()]
    return predicted_class_name, image

# Creating the Gradio interface
def gradio_predict(image):
    predicted_class_name, image = predict(image)
    displayed_image = display_image_with_prediction(predicted_class_name, image)
    return predicted_class_name, displayed_image

iface = gr.Interface(
    fn=gradio_predict,
    inputs=gr.Image(type="pil"),
    outputs=["text", "image"],
    title="Chest X-ray Classification",
    description="Upload a chest x-ray image to classify it as healthy or with tuberculosis."
)

# Launching the interface
iface.launch()

# Defining a function to display the image with the predicted class name
def display_image_with_prediction(predicted_class_name, image):
    image_np = np.array(image)
    plt.imshow(image_np, cmap='gray')
    plt.axis('off')
    plt.text(10, 10, f'Predicted: {predicted_class_name}', fontsize=12, color='white', backgroundcolor='red', weight='bold')
    plt.savefig("predicted_image.png")  # Save the plot as an image file
    return Image.open("predicted_image.png")
# Out:
# * Running on local URL:  http://127.0.0.1:7862
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
